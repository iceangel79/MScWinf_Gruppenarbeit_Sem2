# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Alle verfügbaren Datensätze anzeigen
print(sns.get_dataset_names())

df = sns.load_dataset("flights")
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Ersten 5 Zeilen anzeigen
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Letzten 5 Zeilen anzeigen
df.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
# Spaltennamen anzeigen
df.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
# Datentypen der Spalten prüfen
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df[["year", "passengers"]].corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
df["month_numeric"] = df["month"].cat.codes
df[["month_numeric", "passengers"]].corr()
# Out:
#                month_numeric  passengers
# month_numeric       1.000000    0.063649
# passengers          0.063649    1.000000

# %%
df[["month_numeric", "passengers"]].corr()
# Out:
#                month_numeric  passengers
# month_numeric       1.000000    0.063649
# passengers          0.063649    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.lineplot(x=df["year"], y=df["passengers"])
plt.title("Passengers Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Passengers")
plt.grid(True)
plt.show()

# %%
# Korrelation berechnen
corr_matrix = df[["year", "passengers"]].corr()

# Heatmap erstellen
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap der Korrelationen")
plt.show()

# %%
# 1️⃣ Liniengrafik: Entwicklung der Passagierzahlen über die Jahre
plt.figure(figsize=(10,6))
sns.lineplot(x=df["year"], y=df["passengers"], marker="o", linewidth=2)
plt.title("Passagierentwicklung über die Jahre")
plt.xlabel("Jahr")
plt.ylabel("Anzahl der Passagiere")
plt.grid(True)
plt.show()

# %%
# 2️⃣ Balkendiagramm: Passagiere pro Jahr
plt.figure(figsize=(10,6))
sns.barplot(x=df["year"], y=df["passengers"], palette="Blues")
plt.title("Passagiere pro Jahr")
plt.xlabel("Jahr")
plt.ylabel("Anzahl der Passagiere")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/7f/11912_rn5y34qkv95bl25kvc0000gn/T/ipykernel_63319/2794429398.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["year"], y=df["passengers"], palette="Blues")

# %%
# 3️⃣ Scatterplot: Zusammenhang zwischen Jahr und Passagierzahlen
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["year"], y=df["passengers"], color="red", s=100)
plt.title("Scatterplot: Jahr vs. Passagiere")
plt.xlabel("Jahr")
plt.ylabel("Anzahl der Passagiere")
plt.grid(True)
plt.show()

# %%
# 4️⃣ Boxplot: Verteilung der Passagierzahlen
plt.figure(figsize=(6,6))
sns.boxplot(y=df["passengers"], color="orange")
plt.title("Boxplot der Passagierzahlen")
plt.ylabel("Anzahl der Passagiere")
plt.grid(True)
plt.show()
